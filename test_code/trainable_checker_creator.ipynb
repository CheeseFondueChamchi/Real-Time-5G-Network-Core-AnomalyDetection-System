# %%
import pandas as pd

# %%
df = pd.read_csv("trainable_checker_v4.csv")
# Out:
# /tmp/ipykernel_218149/1655942901.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("trainable_checker_v4.csv")

# %%
df
# Out:
#             DB_name  table_name              port                    col_name  \
# 0       BS_UPF01_5M  PFCPN|PFMC             /PIC0  AS_S_REQ_RX_ATTEMPT(count)
# 1       BS_UPF01_5M  PFCPN|PFMC             /PPC1  AS_S_REQ_RX_ATTEMPT(count)
# 2       BS_UPF01_5M  PFCPN|PFMC            /PPC11  AS_S_REQ_RX_ATTEMPT(count)
# 3       BS_UPF01_5M  PFCPN|PFMC             /PPC2  AS_S_REQ_RX_ATTEMPT(count)
# 4       BS_UPF01_5M  PFCPN|PFMC             /PPC3  AS_S_REQ_RX_ATTEMPT(count)
# ...             ...         ...               ...                         ...
# 763449  HH_AMF22_5M   COSVC|EIR  /PEER10.6.132.36         EIDCHECK_S_RATIO(%)
# 763450  HH_AMF22_5M   COSVC|EIR   /PEER10.6.238.4         EIDCHECK_C_RATIO(%)
# 763451  HH_AMF22_5M   COSVC|EIR   /PEER10.6.238.5         EIDCHECK_C_RATIO(%)
# 763452  HH_AMF22_5M   COSVC|EIR  /PEER10.6.132.35         EIDCHECK_C_RATIO(%)
# 763453  HH_AMF22_5M   COSVC|EIR  /PEER10.6.132.36         EIDCHECK_C_RATIO(%)
#
# ...

# %%
#### 특정 테이블이 통채로 비어질 경우 the type of datetime is Nonetype 과 같은 애러를 보임

condition1 = (df["DB_name"] == "HH_UPF01_5M")
condition2 = (df["table_name"] == "PUD|DROPDTL")
# condition3 = (df["port"] == "/PPC9/0/V4")
# condition4 = (df["col_name"] == "UL_INV_SESS(count)")
check_list = condition1 & condition2 # & condition4 #  & condition4

df.loc[check_list,'AT_model'] = False
df.loc[check_list,['DB_name', 'table_name', 'port', 'col_name', 'col_min', 'col_max',
       'col_avg', 'col_var', 'shape', 'AT_model']]
# Out:
#             DB_name   table_name       port            col_name col_min  \
# 132834  HH_UPF01_5M  PUD|DROPDTL   /PPC0/V4  UL_INV_SESS(count)     0.0
# 132835  HH_UPF01_5M  PUD|DROPDTL   /PPC0/V6  UL_INV_SESS(count)     0.0
# 132836  HH_UPF01_5M  PUD|DROPDTL   /PPC1/V4  UL_INV_SESS(count)     0.0
# 132837  HH_UPF01_5M  PUD|DROPDTL   /PPC1/V6  UL_INV_SESS(count)     0.0
# 132838  HH_UPF01_5M  PUD|DROPDTL  /PPC10/V4  UL_INV_SESS(count)     0.0
# ...             ...          ...        ...                 ...     ...
# 134893  HH_UPF01_5M  PUD|DROPDTL   /PPC7/V6   DL_DUP_GTP(count)     0.0
# 134894  HH_UPF01_5M  PUD|DROPDTL   /PPC8/V4   DL_DUP_GTP(count)     0.0
# 134895  HH_UPF01_5M  PUD|DROPDTL   /PPC8/V6   DL_DUP_GTP(count)     0.0
# 134896  HH_UPF01_5M  PUD|DROPDTL   /PPC9/V4   DL_DUP_GTP(count)     0.0
# 134897  HH_UPF01_5M  PUD|DROPDTL   /PPC9/V6   DL_DUP_GTP(count)     0.0
#
#        col_max     col_avg        col_var    shape  AT_model
# ...

# %%
df.to_csv("trainable_checker_v4.1.csv")
